# %% [markdown]
# <h1><center>xView2</center></h1>
# <h3><center> “The xView2 Challenge focuses on automating the process of assessing building damage after a natural disaster, an analytical bottleneck in the post-disaster workflow. “ - DIU </center></h3>
# <center> <a>https://www.ibm.com/blog/the-xview2-ai-challenge/</a></center>
# <div>
#     <center>
# <img src="pictures/DIU.png" width="600"/>
#         <center>
# </div>

# %% [markdown]
# <h1><center>xBD</center></h1>
# <h3><center>A large-scale dataset for the advancement of change detection and building damage assessment for humanitarian assistance and disaster recovery research. </center></h3>
#
# <table>
#     <row>
#         <td>
#             <h1><center>Pre-disaster Image</center></h1>
#   <div>
#     <center>
# <img src="pictures/pre.png" width="400"/>
#         <center>
# </div>
#             </td>
#             <td>
# <h1><center>Post-disaster Image</center></h1>
# <div>
#     <center>
# <img src="pictures/post.png" width="400"/>
#         <center>
# </div>
#             </td>
#     </row>
# </table>
# <h1><center>Label</center></h1>
# <div>
#     <center>
# <img src="pictures/label.png" width="600"/>
#         <center>
# </div>

# %% [markdown]
# <table>
# <row>
# <td>
# <center>
# <img src="pictures/AreaPerDisaster.png" width="500"/>
# <center>
# </td>
# <td>
# <center>
# <img src="pictures/polygon_overlay.png" width="500"/>
# <center>
# </td>
# </row>
# </table>
# <table>
# <row>
# <td>
# <center>
# <img src="pictures/DamageLabel.png" width="500"/>
# <center>
# </td>
# <td>
#     <center>
# <img src="pictures/PolygonPerDisaster.png" width="500"/>
#         <center>
# </td>
# </row>
# </table>

# %% [markdown]
# <h1>Agenda</h1>
# <h2>1. Segmentation </h2> To find the buildings on the satellite image.
# <h2>2. Classification </h2> To classify the buildings into damage levels.

# %% [markdown]
# <h1><center>Segmentation</center></h1>
#
# <div>
#     <center>
# <img src="pictures/segmentation.png" width="600"/>
#         <center>
# </div>
#
#   <center><h4>For prediction, we train a UNET-based algorithm with satellite images and their masks.  </h4> </center>

# %%
import os
import json
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Image
from skimage.io import imread, imshow
from shapely import wkt
import geopandas
from osgeo import gdal
from osgeo import ogr
import cv2
import tensorflow as tf
import random
from skimage.transform import resize
import matplotlib.pyplot as plt
from osgeo import osr
from PIL import Image as img
from IPython.display import JSON
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from urllib.request import urlopen
import tarfile
from io import BytesIO
# Out:
# 2023-08-01 03:16:38.586834: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-01 03:16:38.733451: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-08-01 03:16:38.775700: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-08-01 03:16:39.511785: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-08-01 03:16:39.511933: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-08-01 03:16:39.511942: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
# download train data
r = urlopen("https://files.bwsi-remote-sensing.net/data/xview/train_images_labels_targets.tar")
t = tarfile.open(name=None, fileobj=BytesIO(r.read()))
t.extractall("../")
t.close()

# download test data
r = urlopen("https://files.bwsi-remote-sensing.net/data/xview/test_images_labels_targets.tar")
t = tarfile.open(name=None, fileobj=BytesIO(r.read()))
t.extractall("../")
t.close()

# create needed folders
folders = ['json','masks','model']
for folder in folders:
    os.makedirs(folder)

# %% [markdown]
# ### Agenda - Segmentation
#
# 1. Data
# 2. Building footprint
# 3. Masks
# 4. Data Augmentation
# 5. Model
# 6. Validation

# %% [markdown]
# ### 1. Data

# %%
train_data_dir = r'../train/images/'
labels_data_dir = r'../train/labels/' 
train_data = [file for file in os.listdir(train_data_dir) if 'pre' in file]
labels_data = [file for file in os.listdir(labels_data_dir)[0:len(os.listdir(labels_data_dir))] if 'pre' in file]
train_data_df = pd.DataFrame({'Train_Data':train_data})
labels_data_df = pd.DataFrame({'Label_Data':labels_data})

# %%
test_data_dir = r'../test/images/'
test_labels_data_dir = r'../test/labels/' 
test_data = [file for file in os.listdir(test_data_dir) if 'pre' in file]
test_labels_data = [file for file in os.listdir(test_labels_data_dir)[0:len(os.listdir(test_labels_data_dir))] if 'pre' in file]
test_data_df = pd.DataFrame({'Test_Data':test_data})
test_labels_data_df = pd.DataFrame({'Test_Label_Data':labels_data})

# %% [markdown]
# #### Images

# %%
train_data_df.head()
# Out:
#                                     Train_Data
# 0   hurricane-harvey_00000141_pre_disaster.png
# 1  hurricane-michael_00000250_pre_disaster.png
# 2         socal-fire_00000545_pre_disaster.png
# 3         socal-fire_00000547_pre_disaster.png
# 4  hurricane-matthew_00000085_pre_disaster.png

# %%
# disaster events and counts
events = [x.split('_')[0] for x in train_data_df.Train_Data]
for event in set(events):
    print(f'{event} = {events.count(event)}')
# Out:
# hurricane-michael = 343
# hurricane-florence = 319
# santa-rosa-wildfire = 226
# guatemala-volcano = 18
# socal-fire = 823
# palu-tsunami = 113
# hurricane-matthew = 238
# hurricane-harvey = 319
# mexico-earthquake = 121
# midwest-flooding = 279

# %% [markdown]
# #### disaster types
#
# 1. volcano,
# 2. hurricane,
# 3. earthquake,
# 4. flooding,
# 5. tsunami,
# 6. wildfire,
# 7. fire.

# %%
train_data_df.count()
# Out:
# Train_Data    2799
# dtype: int64

# %%
image_filename = os.path.join(train_data_dir, train_data[0].title().lower())
img = Image(filename=image_filename)
img.height= 300
img.width = 300
print(image_filename)
display(img)
# Out:
# ../train/images/hurricane-harvey_00000141_pre_disaster.png

# %% [markdown]
# #### Labels

# %%
labels_data_df.head()
# Out:
#                                        Label_Data
# 0   hurricane-florence_00000365_pre_disaster.json
# 1    hurricane-matthew_00000054_pre_disaster.json
# 2           socal-fire_00000378_pre_disaster.json
# 3     hurricane-harvey_00000430_pre_disaster.json
# 4  santa-rosa-wildfire_00000330_pre_disaster.json

# %%
# To visualize the content of JSON file
with open(os.path.join(labels_data_dir, 'midwest-flooding_00000108_pre_disaster.json'), 'r') as f:
                data = json.load(f)
                json_formatted_str = json.dumps(data, indent=2)
                print(json_formatted_str)
# Out:
# {
#   "features": {
#     "lng_lat": [
#       {
#         "properties": {
#           "feature_type": "building",
#           "uid": "e00bc2ea-b2af-4093-8685-048d0066b480"
#         },
#         "wkt": "POLYGON ((-96.2124999551873 36.35194821297325, -96.21253022979653 36.35203504855623, -96.21252561741356 36.35211978417846, -96.21227522379515 36.35214479046068, -96.21225450900431 36.35196819270638, -96.2124999551873 36.35194821297325))"
#       },
#       {
#         "properties": {
#           "feature_type": "building",
#           "uid": "cf7faa40-6311-4fc6-81fb-b77b7d863321"
#         },
#         "wkt": "POLYGON ((-96.2121359497383 36.35189727309382, -96.21195345710693 36.35190130909216, -96.21195023695203 36.35194364132299, -96.211964218681 36.35196701531144, -96.21214327883925 36.35196336010638, -96.21214327407627 36.351931554427, -96.2121359497383 36.35189727309382))"
#       },
#       {
#         "properties": {
#           "feature_type": "building",
#           "uid": "e857d253-560a-414c-a6b4-aba5ef148828"
#         },
#         "wkt": "POLYGON ((-96.21043326602009 36.35231797536184, -96.21050353416 36.35230532704892, -96.21052756058388 36.35233727334197, -96.21052954258215 36.35239924135928, -96.2104295472116 36.35242212812709, -96.21043326602009 36.35231797536184))"
#       },
#       {
#         "properties": {
#           "feature_type": "building",
#           "uid": "8f1facde-f79a-4a57-9f5b-bf8ab7257aca"
#         },
#         "wkt": "POLYGON ((-96.21054308395857 36.35237241395154, -96.21059600878728 36.35253481648344, -96.2106234622518 36.35252952014359, -96.21063485519778 36.35256286776332, -96.21071299432289 36.35254772832871, -96.21070058384814 36.35251350870273, -96.21072483351637 36.35250983398096, -96.21071550578898 36.35247738285677, -96.21075361832507 36.3524672460338, -96.21073319835702 36.35240846321209, -96.21070193783218 36.35241684066814, -96.21067400393579 36.35234748044806, -96.21054308395857 36.35237241395154))"
#       },
#       {
#         "properties": {
#           "feature_type": "building",
#           "uid": "082eaa65-ba6c-445d-a36d-9761541989de"
#         },
#         "wkt": "POLYGON ((-96.21051243999587 36.35226043007511, -96.21049336863686 36.35226592221915, -96.21046193607906 36.3522651878695, -96.21044739945319 36.35221327177073, -96.2104955776682 36.352204052114, -96.21051243999587 36.35226043007511))"
#       },
#       {
#         "properties": {
#           "feature_type": "building",
#           "uid": "a4bdac84-19df-4bce-a2c1-9f116c4fbf16"
#         },
#         "wkt": "POLYGON ((-96.21094244557034 36.35430474635936, -96.21087896463729 36.35431109962057, -96.21091434082925 36.35450137643731, -96.21097502432764 36.35449357496497, -96.21094244557034 36.35430474635936))"
#       },
#       {
#         "properties": {
#           "feature_type": "building",
#           "uid": "64bf6d12-55dc-4a8d-8077-d9eed41f9667"
#         },
#         "wkt": "POLYGON ((-96.21035210112206 36.35459104074824, -96.21038481638526 36.35458751411683, -96.21035747705928 36.35444049272425, -96.21035210112206 36.35459104074824))"
#       },
#       {
#         "properties": {
#           "feature_type": "building",
#           "uid": "43c4c5ae-42b8-421e-bf59-8ced40311c3e"
#         },
#         "wkt": "POLYGON ((-96.21333848241345 36.3547056854657, -96.21333686033368 36.35469256955393, -96.21328783649061 36.35469161054218, -96.21327055152838 36.35470409998557, -96.21333848241345 36.3547056854657))"
#       },
#       {
#         "properties": {
#           "feature_type": "building",
#           "uid": "468fa6bc-e706-4f3d-aca6-9c8ce1d21eaa"
#         },
#         "wkt": "POLYGON ((-96.21332035800091 36.35462271807963, -96.21327003403853 36.35462239177825, -96.21326855260766 36.35466392110838, -96.21332103263546 36.35466260124634, -96.21332035800091 36.35462271807963))"
#       },
#       {
#         "properties": {
#           "feature_type": "building",
#           "uid": "39311f3e-59ef-4e7e-bbc0-52a9b25981f6"
#         },
#         "wkt": "POLYGON ((-96.21463773085651 36.35430578011641, -96.21456204805682 36.35431081949144, -96.21457026993724 36.35443315833437, -96.2145493489102 36.35443359216836, -96.21454998426439 36.35447269983933, -96.21456810503352 36.3544721270209, -96.21456889032173 36.3545306741276, -96.21464654735726 36.35452909278672, -96.21464251649411 36.35440685171741, -96.21466035904602 36.3544064197093, -96.21465883761843 36.35439026759416, -96.21463997750423 36.35438982762078, -96.21463773085651 36.35430578011641))"
#       },
#       {
#         "properties": {
#           "feature_type": "building",
#           "uid": "d568c6bb-35e8-48c7-8242-3354357c5eee"
#         },
#         "wkt": "POLYGON ((-96.21464306170526 36.35462077275756, -96.21459992111778 36.35462485581043, -96.21460290351396 36.35465885511702, -96.21465026548928 36.35465402229807, -96.21464306170526 36.35462077275756))"
#       },
#       {
#         "properties": {
#           "feature_type": "building",
#           "uid": "83408991-2637-430c-84e0-5adb3fc2cb2f"
#         },
#         "wkt": "POLYGON ((-96.21268441229496 36.35198595114239, -96.21268851510284 36.35198902858625, -96.21269320478198 36.35199041591994, -96.21270061624581 36.35198931107583, -96.21270654040045 36.35198561579662, -96.21271045110889 36.35197931780046, -96.21271225727048 36.35197297067585, -96.21271134164849 36.35196911572919, -96.21270740585885 36.35196135670751, -96.21270228114567 36.351957403504, -96.21269655437897 36.35195556600841, -96.21268869269976 36.35195453058, -96.21268177700836 36.35195649890181, -96.21267905522448 36.35195899107904, -96.21267726424428 36.351964912605, -96.21267325254 36.35195928157257, -96.21266910418321 36.3519574809224, -96.21266288164838 36.35195477994689, -96.21265551573875 36.35195460799466, -96.21264649550099 36.35195652718511, -96.21263789511229 36.35196143784345, -96.21263228451863 36.35197110377401, -96.21263304829786 36.35197921470137, -96.21263803635394 36.35198699829003, -96.21264576138108 36.35199186410417, -96.21265622337901 36.35199381214327, -96.21266361965981 36.35199313289953, -96.21267055053859 36.35199073898091, -96.21267655061294 36.35198491571305, -96.2126788069958 36.35198070886154, -96.21267891328125 36.35197772967522, -96.21268065711691 36.35198243078351, -96.21268441229496 36.35198595114239))"
#       },
#       {
#         "properties": {
#           "feature_type": "building",
#           "uid": "4b5c1d81-743f-4cc5-b03d-ebdefbbe96aa"
#         },
#         "wkt": "POLYGON ((-96.21300282716284 36.35185483077812, -96.21301337084311 36.35185238558457, -96.21301824315282 36.35184903907092, -96.21302323879108 36.35184223519595, -96.21302594215786 36.35183307098984, -96.21302528012919 36.35182498164448, -96.21302119789323 36.35181950376485, -96.21301422516119 36.35181511183037, -96.21299723846634 36.35181163956867, -96.21298862178921 36.35181336079797, -96.21297989548441 36.3518181552364, -96.21297287692163 36.35182837213083, -96.21297253433514 36.35183797591129, -96.21297742932998 36.35184731747447, -96.21298676284934 36.35185214898665, -96.21299712838614 36.35185469776043, -96.21300282716284 36.35185483077812))"
#       },
#       {
#         "properties": {
#           "feature_type": "building",
#           "uid": "39b77295-3345-4af7-a7f3-b2bc762b736d"
#         },
#         "wkt": "POLYGON ((-96.21291511703407 36.35186201077251, -96.21292190264428 36.35185832445239, -96.2129259347916 36.35185188256285, -96.21292788857762 36.35184500768889, -96.2129260354488 36.35183573712727, -96.21292200803434 36.35182872263969, -96.21291219962418 36.35182388003757, -96.21290176557568 36.35182325201266, -96.21289024469316 36.35182644332831, -96.21288440888017 36.35183015181723, -96.21287938582321 36.3518377239883, -96.21287955923485 36.35184618639968, -96.21288309804429 36.35185357395446, -96.21289146805809 36.35185876745451, -96.21290088379597 36.35186129406608, -96.21290796621592 36.35186261110337, -96.21291511703407 36.35186201077251))"
#       },
#       {
#         "properties": {
#           "feature_type": "building",
#           "uid": "580ee19b-f6c8-4e0b-83aa-8dcf9a965f9a"
#         },
#         "wkt": "POLYGON ((-96.21159791845176 36.35163108051377, -96.21158720704784 36.35158793933741, -96.21150561189062 36.35160207871706, -96.21151692109852 36.35164481467256, -96.21159791845176 36.35163108051377))"
#       },
#       {
#         "properties": {
#           "feature_type": "building",
#           "uid": "05efb421-c4c8-4941-acc5-bb2b24ee87c4"
#         },
#         "wkt": "POLYGON ((-96.21145746883663 36.35153800860873, -96.21146540640257 36.35153691612764, -96.21147343510802 36.35153327006019, -96.21147736107812 36.35152654650969, -96.21147774082618 36.35151590656866, -96.21147535320044 36.35150903556951, -96.21146971763844 36.35150464443174, -96.21145931650177 36.35150099390201, -96.21144778715021 36.35149944678459, -96.21143610589782 36.35150215564235, -96.21142905350887 36.35150795427066, -96.21142881046596 36.35151476383265, -96.21142093366286 36.35151415392089, -96.21141086118674 36.35151604844367, -96.21140438049856 36.35152058256521, -96.21140246791249 36.35152990884959, -96.21140425344755 36.35153889555031, -96.21140880636126 36.35154411331094, -96.21141857503598 36.35155073074086, -96.21142902174758 36.35155310448145, -96.21143801158162 36.35155203657747, -96.21144447708058 36.35154792805179, -96.21144829985614 36.35154460971135, -96.21144960045919 36.35154066947523, -96.21144810477224 36.35153480825044, -96.21145325977217 36.35153791030888, -96.21145746883663 36.35153800860873))"
#       },
#       {
#         "properties": {
#           "feature_type": "building",
#           "uid": "a66e313a-ab12-4b76-983c-4c25652ae37c"
#         },
#         "wkt": "POLYGON ((-96.21166047988456 36.35156562863396, -96.21166201120556 36.35152272064119, -96.2116438249441 36.3514765207342, -96.21148338105961 36.35150958275391, -96.21150423391532 36.35159548534466, -96.21166047988456 36.35156562863396))"
#       },
#       {
#         "properties": {
#           "feature_type": "building",
#           "uid": "4c96fc5f-9316-40ed-a152-93ca61d8010f"
#         },
#         "wkt": "POLYGON ((-96.21483331664935 36.3543439055189, -96.2148345644558 36.35430890535256, -96.21476225194303 36.35430669569539, -96.21476159404486 36.35434327809623, -96.21483331664935 36.3543439055189))"
#       }
#     ],
#     "xy": [
#       {
#         "properties": {
#           "feature_type": "building",
#           "uid": "e00bc2ea-b2af-4093-8685-048d0066b480"
#         },
#         "wkt": "POLYGON ((617.2285579892292 670.4626622087967, 610.6178186509605 649.3712557486065, 610.9326157623067 628.5946463997624, 660.3557622436481 621.0395157274554, 665.7073131365322 664.1667199818743, 617.2285579892292 670.4626622087967))"
#       },
#       {
#         "properties": {
#           "feature_type": "building",
#           "uid": "cf7faa40-6311-4fc6-81fb-b77b7d863321"
#         },
#         "wkt": "POLYGON ((689.6937758386346 680.855798032161, 725.8148952082281 678.8239850676214, 726.153530702318 668.4391632488631, 723.2186897535386 662.7952383473643, 687.7748413721249 664.7141728138739, 688.0005983681849 672.5027891779425, 689.6937758386346 680.855798032161))"
#       },
#       {
#         "properties": {
#           "feature_type": "building",
#           "uid": "e857d253-560a-414c-a6b4-aba5ef148828"
#         },
#         "wkt": "POLYGON ((1024 568.094886750141, 1010.170231596073 571.5942479606374, 1005.184961393647 563.9086230652296, 1004.354083026575 548.7450928661816, 1024 542.5684436012505, 1024 568.094886750141))"
#       },
#       {
#         "properties": {
#           "feature_type": "building",
#           "uid": "8f1facde-f79a-4a57-9f5b-bf8ab7257aca"
#         },
#         "wkt": "POLYGON ((1001.861447925362 555.3921198027506, 990.2291507863664 515.9253973668725, 984.8284414004041 517.3794345092469, 982.3358062991908 509.2783704303036, 966.9645565083752 513.4327622656591, 969.6649112013563 521.7415459363704, 964.8873605906973 522.7801438952092, 966.9645565083752 530.6734883823848, 959.486651204735 533.3738430753659, 963.9472917986524 547.6518996948557, 970.0803503848919 545.4215793978972, 976.1042185461574 562.2468663310873, 1001.861447925362 555.3921198027506))"
#       },
#       {
#         "properties": {
#           "feature_type": "building",
#           "uid": "082eaa65-ba6c-445d-a36d-9761541989de"
#         },
#         "wkt": "POLYGON ((1008.723634443653 582.6396718698765, 1012.462587095473 581.185634727502, 1018.694174848506 581.185634727502, 1021.940884627345 593.8158009444753, 1012.462587095473 596.3491649265499, 1008.723634443653 582.6396718698765))"
#       },
#       {
#         "properties": {
#           "feature_type": "building",
#           "uid": "a4bdac84-19df-4bce-a2c1-9f116c4fbf16"
#         },
#         "wkt": "POLYGON ((909.0883128214521 84.48272688770473, 921.6178261027799 82.56379242119507, 913.2648172485614 36.17072973087353, 901.2996964573836 38.42829969147312, 909.0883128214521 84.48272688770473))"
#       },
#       {
#         "properties": {
#           "feature_type": "building",
#           "uid": "64bf6d12-55dc-4a8d-8077-d9eed41f9667"
#         },
#         "wkt": "POLYGON ((1024 10.99698653806577, 1017.544656178503 12.04777614738945, 1024 47.89429981691656, 1024 10.99698653806577))"
#       },
#       {
#         "properties": {
#           "feature_type": "building",
#           "uid": "43c4c5ae-42b8-421e-bf59-8ced40311c3e"
#         },
#         "wkt": "POLYGON ((431.6432666515012 0, 432.0572440193824 3.202582207235563, 441.7747170429943 3.157234417761813, 445.1102917355573 0, 431.6432666515012 0))"
#       },
#       {
#         "properties": {
#           "feature_type": "building",
#           "uid": "468fa6bc-e706-4f3d-aca6-9c8ce1d21eaa"
#         },
#         "wkt": "POLYGON ((435.8196014737664 20.21364574528373, 445.7901418786199 20.00592615351596, 445.7901418786199 9.827666156894795, 435.4041622902309 10.45082493219813, 435.8196014737664 20.21364574528373))"
#       },
#       {
#         "properties": {
#           "feature_type": "building",
#           "uid": "39311f3e-59ef-4e7e-bbc0-52a9b25981f6"
#         },
#         "wkt": "POLYGON ((177.1111000181303 105.3536260961799, 192.0669106254104 103.6872152897608, 189.574275524197 73.77559407520063, 193.7152840275373 73.54983707914069, 193.313228176017 63.97669845353066, 189.7278829030883 64.2204928538828, 189.1588363406615 49.88784102190606, 173.7875865498458 50.71871938897718, 175.4493432839881 80.63034060353733, 171.9181102239358 80.8380601953051, 172.3335494074714 84.7847324388929, 176.0725020592914 84.7847324388929, 177.1111000181303 105.3536260961799))"
#       },
#       {
#         "properties": {
#           "feature_type": "building",
#           "uid": "d568c6bb-35e8-48c7-8242-3354357c5eee"
#         },
#         "wkt": "POLYGON ((173.8305457491034 28.24802396691572, 182.3470490115823 27.00170641630905, 181.5161706445112 18.6929227455979, 172.1687890149612 20.14695988797235, 173.8305457491034 28.24802396691572))"
#       },
#       {
#         "properties": {
#           "feature_type": "building",
#           "uid": "83408991-2637-430c-84e0-5adb3fc2cb2f"
#         },
#         "wkt": "POLYGON ((580.4231035170965 662.2757534502603, 579.5886382796029 661.5455963674534, 578.6498648874227 661.2326719033933, 577.1895507218089 661.5455963674534, 576.0421610202553 662.4843697596336, 575.3120039374485 664.0489920799341, 574.9990794733884 665.6136144002345, 575.2076957827618 666.5523877924147, 576.0421610202553 668.4299345767753, 577.0852425671222 669.3687079689555, 578.232632268676 669.7859405877023, 579.7972545889763 669.9945568970757, 581.1532605999033 669.4730161236422, 581.6748013733369 668.847167195522, 581.987725837397 667.3868530299084, 582.8221910748905 668.7428590408354, 583.656656312384 669.1600916595821, 584.9083541686244 669.7859405877023, 586.3686683342381 669.7859405877023, 588.1419069639119 669.2643998142688, 589.8108374388991 668.0127019580285, 590.853918985766 665.6136144002345, 590.6453026763926 663.6317594611872, 589.6022211295257 661.7542126768268, 588.0375988092252 660.6068229752732, 585.9514357154914 660.1895903565264, 584.4911215498776 660.3982066658998, 583.1351155389506 661.02405559402, 581.987725837397 662.4843697596336, 581.5704932186502 663.5274513065006, 581.5704932186502 664.2576083893075, 581.1918375899387 663.1163597264656, 580.4231035170965 662.2757534502603))"
#       },
#       {
#         "properties": {
#           "feature_type": "building",
#           "uid": "4b5c1d81-743f-4cc5-b03d-ebdefbbe96aa"
#         },
#         "wkt": "POLYGON ((518.2754556043952 696.2049181653938, 516.2041536490725 696.8639687875419, 515.2626527602895 697.7113195874467, 514.3211518715065 699.4060211872562, 513.8504014271149 701.6656233203355, 514.0387016048714 703.64277518678, 514.8860524047763 704.9608764310763, 516.2983037379508 705.9965274087376, 519.6877069375698 706.7497281197641, 521.3824085373793 706.2789776753725, 523.0771101371889 705.0550265199546, 524.3952113814852 702.5129741202403, 524.3952113814852 700.1592218982827, 523.3595604038238 697.8996197652033, 521.4765586262577 696.7698186986636, 519.4052566709349 696.2049181653938, 518.2754556043952 696.2049181653938))"
#       },
#       {
#         "properties": {
#           "feature_type": "building",
#           "uid": "39b77295-3345-4af7-a7f3-b2bc762b736d"
#         },
#         "wkt": "POLYGON ((535.5990719580036 693.9453160323144, 534.2809707137073 694.8868169210975, 533.5277700026809 696.4873684320287, 533.1893279312516 698.1820700318382, 533.6219200915592 700.4416721649176, 534.4692708914639 702.1363737647271, 536.4464227579083 703.2661748312668, 538.5177247132311 703.3603249201451, 540.7773268463104 702.5129741202403, 541.9071279128501 701.5714732314573, 542.8486288016331 699.6884714538911, 542.7544787127549 697.6171694985684, 542.0012780017285 695.8283178098806, 540.3065764019188 694.6043666544625, 538.4235746243528 694.0394661211927, 537.0113232911782 693.7574310616683, 535.5990719580036 693.9453160323144))"
#       },
#       {
#         "properties": {
#           "feature_type": "building",
#           "uid": "580ee19b-f6c8-4e0b-83aa-8dcf9a965f9a"
#         },
#         "wkt": "POLYGON ((798.1533674712582 742.9650317496894, 800.5801736117425 753.4682812392281, 816.643319017805 749.5391665355869, 814.1009506801547 739.1385687906544, 798.1533674712582 742.9650317496894))"
#       },
#       {
#         "properties": {
#           "feature_type": "building",
#           "uid": "05efb421-c4c8-4941-acc5-bb2b24ee87c4"
#         },
#         "wkt": "POLYGON ((826.632907832367 764.9534647948279, 825.0682855120666 765.2663892588881, 823.5036631917661 766.2051626510683, 822.7735061089593 767.8740931260554, 822.7735061089593 770.4817969932228, 823.2950468823927 772.1507274682099, 824.4424365839463 773.1938090150769, 826.5285996776803 774.0282742525704, 828.8233790807876 774.3411987166305, 831.1181584838948 773.6110416338237, 832.4741644948219 772.1507274682099, 832.4741644948219 770.4817969932228, 834.0387868151223 770.5861051479095, 836.0206417541696 770.064564374476, 837.2723396104099 768.9171746729224, 837.5852640744699 766.6223952698151, 837.1680314557232 764.4319240213945, 836.2292580635429 763.1802261651542, 834.2474031244957 761.6156038448538, 832.1612400307619 761.0940630714202, 830.388001401088 761.4069875354803, 829.1363035448477 762.4500690823473, 828.4025138598221 763.2845343198409, 828.172736072862 764.2568662295103, 828.5104546167275 765.6836218776349, 827.4673730698605 764.9534647948279, 826.632907832367 764.9534647948279))"
#       },
#       {
#         "properties": {
#           "feature_type": "building",
#           "uid": "a66e313a-ab12-4b76-983c-4c25652ae37c"
#         },
#         "wkt": "POLYGON ((786.2233509301061 759.3508014438436, 786.2233509301062 769.8669613859421, 790.1524656337474 781.076494511036, 821.7009454600427 772.0626431320945, 816.9628953762401 751.1458854450635, 786.2233509301061 759.3508014438436))"
#       },
#       {
#         "properties": {
#           "feature_type": "building",
#           "uid": "4c96fc5f-9316-40ed-a152-93ca61d8010f"
#         },
#         "wkt": "POLYGON ((138.0998347319018 97.13467988573753, 138.0998347319018 105.7127209546559, 152.4392466680042 105.8407514183711, 152.311216204289 96.87861895830713, 138.0998347319018 97.13467988573753))"
#       }
#     ]
#   },
#   "metadata": {
#     "sensor": "WORLDVIEW02",
#     "provider_asset_type": "WORLDVIEW02",
#     "gsd": 2.0809727000000002,
#     "capture_date": "2019-01-26T17:16:23.000Z",
#     "off_nadir_angle": 20.197157,
#     "pan_resolution": 0.5192045,
#     "sun_azimuth": 157.14372,
#     "sun_elevation": 32.06165,
#     "target_azimuth": 245.92258,
#     "disaster": "midwest-flooding",
#     "disaster_type": "flooding",
#     "catalog_id": "103001008CBA2300",
#     "original_width": 1024,
#     "original_height": 1024,
#     "width": 1024,
#     "height": 1024,
#     "id": "MjQ4MjY2Mg.9sWiVdP6QdF4r0xYM2yH-SiRbq4",
#     "img_name": "midwest-flooding_00000108_pre_disaster.png"
#   }
# }

# %% [markdown]
# ### 2. Building footprint

# %% [markdown]
# We need building footprints to create masks for training our algorithm

# %%
# function to create building footprint geometry from geojson files
def building_footprint_from_json(data,labels_data_dir=labels_data_dir):
    xy_geom = []
    file_name = []
    for j in range(len(data)):
        filename = data[j].title()
        df = pd.read_json(os.path.join(labels_data_dir, filename.lower()))
        for i in range(len(df.loc['lng_lat'][0])):
            if 'wkt' in df.loc['xy'][0][i]:
                xy_geom.append(df.loc['xy'][0][i]['wkt'])
            else:
                building_geom.append('')
            file_name.append(filename)
    return pd.DataFrame({'xy':xy_geom,'filename':file_name})

# %%
# create a dataframe to hold the building footprint
building_footprint = building_footprint_from_json(labels_data)

# %%
building_footprint.head()
# Out:
#                                                   xy
# 0  POLYGON ((491.2910771111694 21.67087602260411,...  \
# 1  POLYGON ((473.5214904326542 12.28006266268971,...
# 2  POLYGON ((640.59717488798 0, 634.5993218993137...
# 3  POLYGON ((848.195582715136 795.5441563239626, ...
# 4  POLYGON ((957.4198451968666 797.9151536700596,...
#
#                                         filename
# 0  Hurricane-Florence_00000365_Pre_Disaster.Json
# 1  Hurricane-Florence_00000365_Pre_Disaster.Json
# 2  Hurricane-Florence_00000365_Pre_Disaster.Json
# 3  Hurricane-Florence_00000365_Pre_Disaster.Json
# 4  Hurricane-Florence_00000365_Pre_Disaster.Json

# %%
# create geopandas dataframe from building footprint for train data
geo_df = building_footprint.copy()
geo_df['xy'] = geo_df['xy'].apply(wkt.loads)
geo_df = geopandas.GeoDataFrame(geo_df, geometry='xy')
geo_df[geo_df['filename'].str.contains("00000108")].plot(color='black')
plt.show()

# %%
# create geopandas dataframe from building footprint for test data
test_building_footprint = building_footprint_from_json(test_labels_data,test_labels_data_dir)
test_geo_df = test_building_footprint.copy()
test_geo_df['xy'] = test_geo_df['xy'].apply(wkt.loads)
test_geo_df = geopandas.GeoDataFrame(test_geo_df, geometry='xy')
test_geo_df[test_geo_df['filename'].str.contains("00001074")].plot(color='black')
plt.show()

# %%
test_geo_df.head()
# Out:
#                                                   xy
# 0  POLYGON ((800.969 0.000, 837.697 0.000, 815.17...  \
# 1  POLYGON ((758.658 0.000, 784.091 0.000, 778.79...
# 2  POLYGON ((661.312 0.000, 683.838 0.000, 706.13...
# 3  POLYGON ((760.133 43.822, 766.779 36.329, 788....
# 4  POLYGON ((889.586 34.485, 899.341 14.518, 900....
#
#                                        filename
# 0  Mexico-Earthquake_00000124_Pre_Disaster.Json
# 1  Mexico-Earthquake_00000124_Pre_Disaster.Json
# 2  Mexico-Earthquake_00000124_Pre_Disaster.Json
# 3  Mexico-Earthquake_00000124_Pre_Disaster.Json
# 4  Mexico-Earthquake_00000124_Pre_Disaster.Json

# %% [markdown]
# ### 3. Masks

# %%
def create_poly_mask(rasterSrc, vectorSrc, npDistFileName='', 
                            noDataValue=0, burn_values=1):
    
    from PIL import ImageFile, Image as img   
    ImageFile.LOAD_TRUNCATED_IMAGES = True
    
    ## open source vector file that truth data
    source_ds = ogr.Open(vectorSrc)
    source_layer = source_ds.GetLayer()

    ## extract data from src Raster File to be emulated
    ## open raster file that is to be emulated
    srcRas_ds = gdal.Open(rasterSrc)
    cols = srcRas_ds.RasterXSize
    rows = srcRas_ds.RasterYSize

    if npDistFileName == '':
        dstPath = ".tmp.tiff"
    else:
        dstPath = npDistFileName

    ## create First raster memory layer, units are pixels
    # Change output to geotiff instead of memory 
    memdrv = gdal.GetDriverByName('GTiff') 
    dst_ds = memdrv.Create(dstPath, cols, rows, 1, gdal.GDT_Byte, 
                           options=['COMPRESS=LZW'])
    dst_ds.SetGeoTransform(srcRas_ds.GetGeoTransform())
    dst_ds.SetProjection(srcRas_ds.GetProjection())
    band = dst_ds.GetRasterBand(1)
    band.SetNoDataValue(noDataValue)    
    gdal.RasterizeLayer(dst_ds, [1], source_layer, burn_values=[burn_values])
    dst_ds = 0

    mask_image = img.open(dstPath)
    mask_image = np.array(mask_image)
    return mask_image,np.array(img.open(rasterSrc))

# %%
def image_mask_pair(row,geo_df,raster_source_folder,json_dest_folder,mask_dest_folder):
    filename = row.title()
    row_df = geo_df[geo_df['filename'].str.contains(filename.split('.')[0])]
    json_file = json_dest_folder+filename.split('.')[0] +".json"
    if len(row_df)!=0:
        row_df.to_file(json_file, driver="GeoJSON")
        raster_file = raster_source_folder + filename.lower()
        mask_file = mask_dest_folder + filename + '.tif'
        label, image = create_poly_mask(raster_file, json_file, npDistFileName=mask_file, 
                                    noDataValue=0, burn_values=255)
        return label, image
    else:
        return None, None

# %%
# create masks - train
json_dest_folder = "./json/"
mask_dest_folder = './masks/'

IMG_HEIGHT = 128
IMG_WIDTH = 128
IMG_CHANNELS = 3

N = 400 #len(train_data)

x_train = np.zeros((N, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
y_train = np.zeros((N, IMG_HEIGHT, IMG_WIDTH))

for i in range(N):
    label, image = image_mask_pair(train_data[i],geo_df,train_data_dir,json_dest_folder,mask_dest_folder)
    if (image is not None) & (label is not None):
        x_train[i] = resize(image, (IMG_HEIGHT, IMG_WIDTH))
        y_train[i] = resize(label, (IMG_HEIGHT, IMG_WIDTH))
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /opt/conda/share/proj failed

# %%
# create masks - test
json_dest_folder = "./json/"
mask_dest_folder = './masks/'

IMG_HEIGHT = 128
IMG_WIDTH = 128
IMG_CHANNELS = 3

N = 30 #len(test_data)

x_test = np.zeros((N, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
y_test = np.zeros((N, IMG_HEIGHT, IMG_WIDTH))

for i in range(N):
    label, image = image_mask_pair(test_data[i],test_geo_df,test_data_dir,json_dest_folder,mask_dest_folder)
    if (image is not None) & (label is not None):
        x_test[i] = resize(image, (IMG_HEIGHT, IMG_WIDTH))
        y_test[i] = resize(label, (IMG_HEIGHT, IMG_WIDTH))

# %%
len(x_train),len(x_test)
# Out:
# (2799, 933)

# %%
len(x_train),len(x_test)
# Out:
# (400, 30)

# %% [markdown]
# ### 4. Data Augmentation

# %%
def image_mask_generator(image_data_generator, mask_data_generator):
    gen = zip(image_data_generator, mask_data_generator)
    for (img, mask) in gen:
        yield (img, mask)

# %%
# Train data

SEED = 100

train_image_data_generator = ImageDataGenerator(
    width_shift_range = 0.1,
    height_shift_range = 0.1,
    rotation_range = 10,
    zoom_range = 0.1
).flow(x_train, batch_size = 16, seed = SEED)

train_mask_data_generator = ImageDataGenerator(
    width_shift_range = 0.1,
    height_shift_range = 0.1,
    rotation_range = 10,
    zoom_range = 0.1
).flow(y_train.reshape(len(y_train),128,128,1), batch_size = 16, seed = SEED)

# %%
# Test data

SEED = 100

test_image_data_generator = ImageDataGenerator(
    width_shift_range = 0.1,
    height_shift_range = 0.1,
    rotation_range = 10,
    zoom_range = 0.1
).flow(x_test, batch_size = 16, seed = SEED)

test_mask_data_generator = ImageDataGenerator(
    width_shift_range = 0.1,
    height_shift_range = 0.1,
    rotation_range = 10,
    zoom_range = 0.1
).flow(y_test.reshape(len(y_test),128,128,1), batch_size = 16, seed = SEED)

# %%
train_generator = image_mask_generator(train_image_data_generator, train_mask_data_generator)
test_generator = image_mask_generator(test_image_data_generator, test_mask_data_generator)

# %% [markdown]
# ### 5. Model

# %%
Image(url="pictures/unet.jpeg", width=900, height=900)
# Out:
# <img src="pictures/unet.jpeg" width="900" height="900"/>

# %%
# unet model
def get_UNET(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS):
    # Build U-Net model
    inputs = tf.keras.layers.Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))

    c1 = tf.keras.layers.Conv2D(16, (3, 3), activation=tf.keras.activations.elu, kernel_initializer='he_normal',
                                padding='same')(inputs)
    c1 = tf.keras.layers.Dropout(0.1)(c1)
    c1 = tf.keras.layers.Conv2D(16, (3, 3), activation=tf.keras.activations.elu, kernel_initializer='he_normal',
                                padding='same')(c1)
    p1 = tf.keras.layers.MaxPooling2D((2, 2))(c1)

    c2 = tf.keras.layers.Conv2D(32, (3, 3), activation=tf.keras.activations.elu, kernel_initializer='he_normal',
                                padding='same')(p1)
    c2 = tf.keras.layers.Dropout(0.1)(c2)
    c2 = tf.keras.layers.Conv2D(32, (3, 3), activation=tf.keras.activations.elu, kernel_initializer='he_normal',
                                padding='same')(c2)
    p2 = tf.keras.layers.MaxPooling2D((2, 2))(c2)

    c3 = tf.keras.layers.Conv2D(64, (3, 3), activation=tf.keras.activations.elu, kernel_initializer='he_normal',
                                padding='same')(p2)
    c3 = tf.keras.layers.Dropout(0.2)(c3)
    c3 = tf.keras.layers.Conv2D(64, (3, 3), activation=tf.keras.activations.elu, kernel_initializer='he_normal',
                                padding='same')(c3)
    p3 = tf.keras.layers.MaxPooling2D((2, 2))(c3)

    c4 = tf.keras.layers.Conv2D(128, (3, 3), activation=tf.keras.activations.elu, kernel_initializer='he_normal',
                                padding='same')(p3)
    c4 = tf.keras.layers.Dropout(0.2)(c4)
    c4 = tf.keras.layers.Conv2D(128, (3, 3), activation=tf.keras.activations.elu, kernel_initializer='he_normal',
                                padding='same')(c4)
    p4 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(c4)

    c5 = tf.keras.layers.Conv2D(256, (3, 3), activation=tf.keras.activations.elu, kernel_initializer='he_normal',
                                padding='same')(p4)
    c5 = tf.keras.layers.Dropout(0.3)(c5)
    c5 = tf.keras.layers.Conv2D(256, (3, 3), activation=tf.keras.activations.elu, kernel_initializer='he_normal',
                                padding='same')(c5)

    u6 = tf.keras.layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = tf.keras.layers.concatenate([u6, c4])
    c6 = tf.keras.layers.Conv2D(128, (3, 3), activation=tf.keras.activations.elu, kernel_initializer='he_normal',
                                padding='same')(u6)
    c6 = tf.keras.layers.Dropout(0.2)(c6)
    c6 = tf.keras.layers.Conv2D(128, (3, 3), activation=tf.keras.activations.elu, kernel_initializer='he_normal',
                                padding='same')(c6)

    u7 = tf.keras.layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = tf.keras.layers.concatenate([u7, c3])
    c7 = tf.keras.layers.Conv2D(64, (3, 3), activation=tf.keras.activations.elu, kernel_initializer='he_normal',
                                padding='same')(u7)
    c7 = tf.keras.layers.Dropout(0.2)(c7)
    c7 = tf.keras.layers.Conv2D(64, (3, 3), activation=tf.keras.activations.elu, kernel_initializer='he_normal',
                                padding='same')(c7)

    u8 = tf.keras.layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = tf.keras.layers.concatenate([u8, c2])
    c8 = tf.keras.layers.Conv2D(32, (3, 3), activation=tf.keras.activations.elu, kernel_initializer='he_normal',
                                padding='same')(u8)
    c8 = tf.keras.layers.Dropout(0.1)(c8)
    c8 = tf.keras.layers.Conv2D(32, (3, 3), activation=tf.keras.activations.elu, kernel_initializer='he_normal',
                                padding='same')(c8)

    u9 = tf.keras.layers.Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = tf.keras.layers.concatenate([u9, c1], axis=3)
    c9 = tf.keras.layers.Conv2D(16, (3, 3), activation=tf.keras.activations.elu, kernel_initializer='he_normal',
                                padding='same')(u9)
    c9 = tf.keras.layers.Dropout(0.1)(c9)
    c9 = tf.keras.layers.Conv2D(16, (3, 3), activation=tf.keras.activations.elu, kernel_initializer='he_normal',
                                padding='same')(c9)

    outputs = tf.keras.layers.Conv2D(1, (1, 1), activation='sigmoid')(c9)

    model = tf.keras.Model(inputs=[inputs], outputs=[outputs])
    return model

# %%
IMG_HEIGHT = 128
IMG_WIDTH = 128
IMG_CHANNELS = 3

model = get_UNET(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)

# %%
model.compile(optimizer = Adam(learning_rate = 1e-4), loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# ### Let's start with a smaller sample set

# %%
result = model.fit(train_generator,steps_per_epoch= len(x_train)/ 32, epochs=100)
# Out:
# Epoch 1/100
# 12/12 [==============================] - 2s 81ms/step - loss: 0.4412 - accuracy: 0.7739
# Epoch 2/100
# 12/12 [==============================] - 1s 79ms/step - loss: 0.2747 - accuracy: 0.8635
# Epoch 3/100
# 12/12 [==============================] - 1s 80ms/step - loss: 0.2616 - accuracy: 0.8394
# Epoch 4/100
# 12/12 [==============================] - 1s 79ms/step - loss: 0.2192 - accuracy: 0.8448
# Epoch 5/100
# 12/12 [==============================] - 1s 80ms/step - loss: 0.1932 - accuracy: 0.8595
# Epoch 6/100
# 12/12 [==============================] - 1s 79ms/step - loss: 0.2129 - accuracy: 0.8357
# Epoch 7/100
# 12/12 [==============================] - 1s 81ms/step - loss: 0.1875 - accuracy: 0.8548
# Epoch 8/100
# 12/12 [==============================] - 1s 81ms/step - loss: 0.1838 - accuracy: 0.8512
# Epoch 9/100
# 12/12 [==============================] - 1s 79ms/step - loss: 0.2083 - accuracy: 0.8276
# Epoch 10/100
# 12/12 [==============================] - 1s 78ms/step - loss: 0.1781 - accuracy: 0.8519
# Epoch 11/100
# 12/12 [==============================] - 1s 80ms/step - loss: 0.1948 - accuracy: 0.8386
# Epoch 12/100
# 12/12 [==============================] - 1s 79ms/step - loss: 0.1654 - accuracy: 0.8619
# Epoch 13/100
# 12/12 [==============================] - 1s 78ms/step - loss: 0.1994 - accuracy: 0.8320
# Epoch 14/100
# 12/12 [==============================] - 1s 79ms/step - loss: 0.1673 - accuracy: 0.8640
# Epoch 15/100
# 12/12 [==============================] - 1s 79ms/step - loss: 0.1744 - accuracy: 0.8478
# Epoch 16/100
# 12/12 [==============================] - 1s 80ms/step - loss: 0.1917 - accuracy: 0.8305
# Epoch 17/100
# 12/12 [==============================] - 1s 80ms/step - loss: 0.1742 - accuracy: 0.8558
# Epoch 18/100
# 12/12 [==============================] - 1s 80ms/step - loss: 0.1807 - accuracy: 0.8445
# Epoch 19/100
# 12/12 [==============================] - 1s 80ms/step - loss: 0.1789 - accuracy: 0.8524
# Epoch 20/100
# 12/12 [==============================] - 1s 79ms/step - loss: 0.1730 - accuracy: 0.8548
# Epoch 21/100
# 12/12 [==============================] - 1s 80ms/step - loss: 0.1893 - accuracy: 0.8320
# Epoch 22/100
# 12/12 [==============================] - 1s 80ms/step - loss: 0.1738 - accuracy: 0.8447
# Epoch 23/100
# 12/12 [==============================] - 1s 79ms/step - loss: 0.1817 - accuracy: 0.8434
# Epoch 24/100
# 12/12 [==============================] - 1s 79ms/step - loss: 0.1742 - accuracy: 0.8518
# Epoch 25/100
# 12/12 [==============================] - 1s 80ms/step - loss: 0.1656 - accuracy: 0.8499
# Epoch 26/100
# 12/12 [==============================] - 1s 80ms/step - loss: 0.1765 - accuracy: 0.8400
# Epoch 27/100
# 12/12 [==============================] - 1s 81ms/step - loss: 0.1707 - accuracy: 0.8534
# Epoch 28/100
# 12/12 [==============================] - 1s 80ms/step - loss: 0.1714 - accuracy: 0.8448
# Epoch 29/100
# 12/12 [==============================] - 1s 79ms/step - loss: 0.1697 - accuracy: 0.8555
# Epoch 30/100
# 12/12 [==============================] - 1s 81ms/step - loss: 0.1554 - accuracy: 0.8624
# Epoch 31/100
# 12/12 [==============================] - 1s 78ms/step - loss: 0.1925 - accuracy: 0.8258
# Epoch 32/100
# 12/12 [==============================] - 1s 77ms/step - loss: 0.1881 - accuracy: 0.8270
# Epoch 33/100
# 12/12 [==============================] - 1s 80ms/step - loss: 0.1614 - accuracy: 0.8613
# Epoch 34/100
# 12/12 [==============================] - 1s 79ms/step - loss: 0.1790 - accuracy: 0.8463
# Epoch 35/100
# 12/12 [==============================] - 1s 79ms/step - loss: 0.1647 - accuracy: 0.8544
# Epoch 36/100
# 12/12 [==============================] - 1s 81ms/step - loss: 0.1844 - accuracy: 0.8329
# Epoch 37/100
# 12/12 [==============================] - 1s 79ms/step - loss: 0.1597 - accuracy: 0.8467
# Epoch 38/100
# 12/12 [==============================] - 1s 78ms/step - loss: 0.1666 - accuracy: 0.8559
# Epoch 39/100
# 12/12 [==============================] - 1s 79ms/step - loss: 0.1541 - accuracy: 0.8626
# Epoch 40/100
# 12/12 [==============================] - 1s 80ms/step - loss: 0.1881 - accuracy: 0.8308
# Epoch 41/100
# 12/12 [==============================] - 1s 78ms/step - loss: 0.1645 - accuracy: 0.8468
# Epoch 42/100
# 12/12 [==============================] - 1s 80ms/step - loss: 0.1525 - accuracy: 0.8628
# Epoch 43/100
# 12/12 [==============================] - 1s 80ms/step - loss: 0.1966 - accuracy: 0.8138
# Epoch 44/100
# 12/12 [==============================] - 1s 78ms/step - loss: 0.1683 - accuracy: 0.8512
# Epoch 45/100
# 12/12 [==============================] - 1s 80ms/step - loss: 0.1572 - accuracy: 0.8531
# Epoch 46/100
# 12/12 [==============================] - 1s 80ms/step - loss: 0.1629 - accuracy: 0.8515
# Epoch 47/100
# 12/12 [==============================] - 1s 81ms/step - loss: 0.1564 - accuracy: 0.8516
# Epoch 48/100
# 12/12 [==============================] - 1s 79ms/step - loss: 0.1736 - accuracy: 0.8399
# Epoch 49/100
# 12/12 [==============================] - 1s 78ms/step - loss: 0.1738 - accuracy: 0.8400
# Epoch 50/100
# 12/12 [==============================] - 1s 80ms/step - loss: 0.1551 - accuracy: 0.8532
# Epoch 51/100
# 12/12 [==============================] - 1s 79ms/step - loss: 0.1674 - accuracy: 0.8437
# Epoch 52/100
# 12/12 [==============================] - 1s 80ms/step - loss: 0.1613 - accuracy: 0.8496
# Epoch 53/100
# 12/12 [==============================] - 1s 82ms/step - loss: 0.1672 - accuracy: 0.8435
# Epoch 54/100
# 12/12 [==============================] - 1s 79ms/step - loss: 0.1575 - accuracy: 0.8532
# Epoch 55/100
# 12/12 [==============================] - 1s 79ms/step - loss: 0.1539 - accuracy: 0.8612
# Epoch 56/100
# 12/12 [==============================] - 1s 80ms/step - loss: 0.1832 - accuracy: 0.8240
# Epoch 57/100
# 12/12 [==============================] - 1s 78ms/step - loss: 0.1672 - accuracy: 0.8364
# Epoch 58/100
# 12/12 [==============================] - 1s 77ms/step - loss: 0.1574 - accuracy: 0.8540
# Epoch 59/100
# 12/12 [==============================] - 1s 79ms/step - loss: 0.1704 - accuracy: 0.8373
# Epoch 60/100
# 12/12 [==============================] - 1s 81ms/step - loss: 0.1474 - accuracy: 0.8652
# Epoch 61/100
# 12/12 [==============================] - 1s 77ms/step - loss: 0.1623 - accuracy: 0.8420
# Epoch 62/100
# 12/12 [==============================] - 1s 80ms/step - loss: 0.1421 - accuracy: 0.8734
# Epoch 63/100
# 12/12 [==============================] - 1s 79ms/step - loss: 0.1783 - accuracy: 0.8306
# Epoch 64/100
# 12/12 [==============================] - 1s 81ms/step - loss: 0.1532 - accuracy: 0.8540
# Epoch 65/100
# 12/12 [==============================] - 1s 80ms/step - loss: 0.1492 - accuracy: 0.8531
# Epoch 66/100
# 12/12 [==============================] - 1s 79ms/step - loss: 0.1697 - accuracy: 0.8394
# Epoch 67/100
# 12/12 [==============================] - 1s 80ms/step - loss: 0.1572 - accuracy: 0.8477
# Epoch 68/100
# 12/12 [==============================] - 1s 80ms/step - loss: 0.1605 - accuracy: 0.8425
# Epoch 69/100
# 12/12 [==============================] - 1s 78ms/step - loss: 0.1694 - accuracy: 0.8437
# Epoch 70/100
# 12/12 [==============================] - 1s 82ms/step - loss: 0.1645 - accuracy: 0.8469
# Epoch 71/100
# 12/12 [==============================] - 1s 79ms/step - loss: 0.1578 - accuracy: 0.8471
# Epoch 72/100
# 12/12 [==============================] - 1s 79ms/step - loss: 0.1708 - accuracy: 0.8329
# Epoch 73/100
# 12/12 [==============================] - 1s 78ms/step - loss: 0.1506 - accuracy: 0.8579
# Epoch 74/100
# 12/12 [==============================] - 1s 79ms/step - loss: 0.1339 - accuracy: 0.8696
# Epoch 75/100
# 12/12 [==============================] - 1s 77ms/step - loss: 0.1814 - accuracy: 0.8184
# Epoch 76/100
# 12/12 [==============================] - 1s 78ms/step - loss: 0.1517 - accuracy: 0.8525
# Epoch 77/100
# 12/12 [==============================] - 1s 80ms/step - loss: 0.1578 - accuracy: 0.8402
# Epoch 78/100
# 12/12 [==============================] - 1s 80ms/step - loss: 0.1492 - accuracy: 0.8504
# Epoch 79/100
# 12/12 [==============================] - 1s 79ms/step - loss: 0.1638 - accuracy: 0.8383
# Epoch 80/100
# 12/12 [==============================] - 1s 80ms/step - loss: 0.1591 - accuracy: 0.8466
# Epoch 81/100
# 12/12 [==============================] - 1s 77ms/step - loss: 0.1635 - accuracy: 0.8432
# Epoch 82/100
# 12/12 [==============================] - 1s 79ms/step - loss: 0.1547 - accuracy: 0.8489
# Epoch 83/100
# 12/12 [==============================] - 1s 78ms/step - loss: 0.1511 - accuracy: 0.8514
# Epoch 84/100
# 12/12 [==============================] - 1s 80ms/step - loss: 0.1749 - accuracy: 0.8278
# Epoch 85/100
# 12/12 [==============================] - 1s 78ms/step - loss: 0.1428 - accuracy: 0.8508
# Epoch 86/100
# 12/12 [==============================] - 1s 77ms/step - loss: 0.1584 - accuracy: 0.8407
# Epoch 87/100
# 12/12 [==============================] - 1s 79ms/step - loss: 0.1518 - accuracy: 0.8502
# Epoch 88/100
# 12/12 [==============================] - 1s 80ms/step - loss: 0.1498 - accuracy: 0.8436
# Epoch 89/100
# 12/12 [==============================] - 1s 79ms/step - loss: 0.1711 - accuracy: 0.8249
# Epoch 90/100
# 12/12 [==============================] - 1s 79ms/step - loss: 0.1400 - accuracy: 0.8589
# Epoch 91/100
# 12/12 [==============================] - 1s 80ms/step - loss: 0.1403 - accuracy: 0.8613
# Epoch 92/100
# 12/12 [==============================] - 1s 79ms/step - loss: 0.1670 - accuracy: 0.8429
# Epoch 93/100
# 12/12 [==============================] - 1s 81ms/step - loss: 0.1530 - accuracy: 0.8523
# Epoch 94/100
# 12/12 [==============================] - 1s 80ms/step - loss: 0.1562 - accuracy: 0.8448
# Epoch 95/100
# 12/12 [==============================] - 1s 79ms/step - loss: 0.1582 - accuracy: 0.8376
# Epoch 96/100
# 12/12 [==============================] - 1s 79ms/step - loss: 0.1399 - accuracy: 0.8560
# Epoch 97/100
# 12/12 [==============================] - 1s 80ms/step - loss: 0.1542 - accuracy: 0.8419
# Epoch 98/100
# 12/12 [==============================] - 1s 81ms/step - loss: 0.1492 - accuracy: 0.8494
# Epoch 99/100
# 12/12 [==============================] - 1s 79ms/step - loss: 0.1583 - accuracy: 0.8412
# Epoch 100/100
# 12/12 [==============================] - 1s 80ms/step - loss: 0.1424 - accuracy: 0.8486

# %%
# loss curve
plt.title('Loss')
plt.plot(result.history['loss'], label='loss')
plt.legend(loc='center right')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc='center right');

# %%
# Evaluate the restored model
loss, acc = model.evaluate(x_test, y_test, verbose=2)
print('model accuracy: {:5.2f}%'.format(100 * acc))
# Out:
# 1/1 - 1s - loss: 0.6961 - accuracy: 0.8147 - 863ms/epoch - 863ms/step
# model accuracy: 81.47%

# %%
# What pixels are classified as buildings?
idx = 23
print(idx)
x=np.array(x_test[idx])
x=np.expand_dims(x,axis=0)
pred = model.predict(x, verbose=1)
pred = (pred>0.3).astype(np.uint8)
imshow(np.squeeze(pred[0]));
plt.show()
imshow(x_test[idx]);
# Out:
# 23
# 1/1 [==============================] - 0s 21ms/step

# %% [markdown]
# ### Now, let's consider the whole dataset

# %%
result = model.fit(train_generator,steps_per_epoch= len(x_train)/ 32, epochs=100)
# Out:
# Epoch 1/100
# 2023-07-17 22:04:20.694494: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 33554432 exceeds 10% of free system memory.
# 2023-07-17 22:04:21.187838: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 30408704 exceeds 10% of free system memory.
# 2023-07-17 22:04:21.246090: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 28311552 exceeds 10% of free system memory.
# 2023-07-17 22:04:21.515881: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 37748736 exceeds 10% of free system memory.
# 2023-07-17 22:04:21.516344: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 33554432 exceeds 10% of free system memory.
# 87/87 [==============================] - 540s 6s/step - loss: 0.2635 - accuracy: 0.8215
# Epoch 2/100
# 87/87 [==============================] - 525s 6s/step - loss: 0.1853 - accuracy: 0.8369
# Epoch 3/100
# 87/87 [==============================] - 524s 6s/step - loss: 0.1858 - accuracy: 0.8327
# Epoch 4/100
# 87/87 [==============================] - 523s 6s/step - loss: 0.1743 - accuracy: 0.8401
# Epoch 5/100
# 87/87 [==============================] - 527s 6s/step - loss: 0.1694 - accuracy: 0.8387
# Epoch 6/100
# 87/87 [==============================] - 517s 6s/step - loss: 0.1664 - accuracy: 0.8389
# Epoch 7/100
# 87/87 [==============================] - 519s 6s/step - loss: 0.1586 - accuracy: 0.8424
# Epoch 8/100
# 87/87 [==============================] - 523s 6s/step - loss: 0.1708 - accuracy: 0.8301
# Epoch 9/100
# 87/87 [==============================] - 526s 6s/step - loss: 0.1629 - accuracy: 0.8313
# Epoch 10/100
# 87/87 [==============================] - 529s 6s/step - loss: 0.1550 - accuracy: 0.8417
# Epoch 11/100
# 87/87 [==============================] - 526s 6s/step - loss: 0.1580 - accuracy: 0.8353
# Epoch 12/100
# 87/87 [==============================] - 530s 6s/step - loss: 0.1565 - accuracy: 0.8353
# Epoch 13/100
# 87/87 [==============================] - 527s 6s/step - loss: 0.1561 - accuracy: 0.8315
# Epoch 14/100
# 87/87 [==============================] - 534s 6s/step - loss: 0.1449 - accuracy: 0.8411
# Epoch 15/100
# 87/87 [==============================] - 527s 6s/step - loss: 0.1485 - accuracy: 0.8363
# Epoch 16/100
# 87/87 [==============================] - 527s 6s/step - loss: 0.1451 - accuracy: 0.8378
# Epoch 17/100
# 87/87 [==============================] - 483s 6s/step - loss: 0.1476 - accuracy: 0.8355
# Epoch 18/100
# 87/87 [==============================] - 187s 2s/step - loss: 0.1465 - accuracy: 0.8340
# Epoch 19/100
# 87/87 [==============================] - 198s 2s/step - loss: 0.1402 - accuracy: 0.8401
# Epoch 20/100
# 87/87 [==============================] - 209s 2s/step - loss: 0.1409 - accuracy: 0.8372
# Epoch 21/100
# 87/87 [==============================] - 209s 2s/step - loss: 0.1449 - accuracy: 0.8355
# Epoch 22/100
# 87/87 [==============================] - 199s 2s/step - loss: 0.1399 - accuracy: 0.8372
# Epoch 23/100
# 87/87 [==============================] - 181s 2s/step - loss: 0.1371 - accuracy: 0.8411
# Epoch 24/100
# 87/87 [==============================] - 191s 2s/step - loss: 0.1391 - accuracy: 0.8353
# Epoch 25/100
# 87/87 [==============================] - 349s 4s/step - loss: 0.1402 - accuracy: 0.8349
# Epoch 26/100
# 87/87 [==============================] - 395s 5s/step - loss: 0.1379 - accuracy: 0.8344
# Epoch 27/100
# 87/87 [==============================] - 392s 4s/step - loss: 0.1358 - accuracy: 0.8348
# Epoch 28/100
# 87/87 [==============================] - 391s 4s/step - loss: 0.1325 - accuracy: 0.8391
# Epoch 29/100
# 87/87 [==============================] - 391s 4s/step - loss: 0.1317 - accuracy: 0.8401
# Epoch 30/100
# 87/87 [==============================] - 392s 4s/step - loss: 0.1324 - accuracy: 0.8361
# Epoch 31/100
# 87/87 [==============================] - 391s 4s/step - loss: 0.1337 - accuracy: 0.8388
# Epoch 32/100
# 87/87 [==============================] - 391s 4s/step - loss: 0.1311 - accuracy: 0.8355
# Epoch 33/100
# 87/87 [==============================] - 392s 4s/step - loss: 0.1324 - accuracy: 0.8353
# Epoch 34/100
# 87/87 [==============================] - 393s 4s/step - loss: 0.1319 - accuracy: 0.8356
# Epoch 35/100
# 87/87 [==============================] - 374s 4s/step - loss: 0.1286 - accuracy: 0.8375
# Epoch 36/100
# 87/87 [==============================] - 391s 4s/step - loss: 0.1261 - accuracy: 0.8417
# Epoch 37/100
# 87/87 [==============================] - 391s 4s/step - loss: 0.1286 - accuracy: 0.8391
# Epoch 38/100
# 87/87 [==============================] - 391s 4s/step - loss: 0.1330 - accuracy: 0.8322
# Epoch 39/100
# 87/87 [==============================] - 390s 4s/step - loss: 0.1263 - accuracy: 0.8385
# Epoch 40/100
# 87/87 [==============================] - 390s 4s/step - loss: 0.1309 - accuracy: 0.8334
# Epoch 41/100
# 87/87 [==============================] - 389s 4s/step - loss: 0.1264 - accuracy: 0.8350
# Epoch 42/100
# 87/87 [==============================] - 390s 4s/step - loss: 0.1282 - accuracy: 0.8383
# Epoch 43/100
# 87/87 [==============================] - 389s 4s/step - loss: 0.1230 - accuracy: 0.8402
# Epoch 44/100
# 87/87 [==============================] - 392s 4s/step - loss: 0.1237 - accuracy: 0.8404
# Epoch 45/100
# 87/87 [==============================] - 393s 5s/step - loss: 0.1254 - accuracy: 0.8370
# Epoch 46/100
# 87/87 [==============================] - 377s 4s/step - loss: 0.1237 - accuracy: 0.8366
# Epoch 47/100
# 87/87 [==============================] - 392s 4s/step - loss: 0.1278 - accuracy: 0.8340
# Epoch 48/100
# 87/87 [==============================] - 390s 4s/step - loss: 0.1245 - accuracy: 0.8407
# Epoch 49/100
# 87/87 [==============================] - 392s 4s/step - loss: 0.1239 - accuracy: 0.8359
# Epoch 50/100
# 87/87 [==============================] - 389s 4s/step - loss: 0.1208 - accuracy: 0.8421
# Epoch 51/100
# 87/87 [==============================] - 392s 4s/step - loss: 0.1186 - accuracy: 0.8429
# Epoch 52/100
# 87/87 [==============================] - 391s 4s/step - loss: 0.1233 - accuracy: 0.8327
# Epoch 53/100
# 87/87 [==============================] - 394s 5s/step - loss: 0.1264 - accuracy: 0.8332
# Epoch 54/100
# 87/87 [==============================] - 393s 4s/step - loss: 0.1202 - accuracy: 0.8400
# Epoch 55/100
# 87/87 [==============================] - 390s 4s/step - loss: 0.1238 - accuracy: 0.8321
# Epoch 56/100
# 87/87 [==============================] - 389s 4s/step - loss: 0.1179 - accuracy: 0.8424
# Epoch 57/100
# 87/87 [==============================] - 379s 4s/step - loss: 0.1203 - accuracy: 0.8386
# Epoch 58/100
# 87/87 [==============================] - 391s 4s/step - loss: 0.1153 - accuracy: 0.8429
# Epoch 59/100
# 87/87 [==============================] - 392s 4s/step - loss: 0.1143 - accuracy: 0.8453
# Epoch 60/100
# 87/87 [==============================] - 392s 4s/step - loss: 0.1242 - accuracy: 0.8288
# Epoch 61/100
# 87/87 [==============================] - 388s 4s/step - loss: 0.1276 - accuracy: 0.8249
# Epoch 62/100
# 87/87 [==============================] - 394s 5s/step - loss: 0.1120 - accuracy: 0.8474
# Epoch 63/100
# 87/87 [==============================] - 392s 4s/step - loss: 0.1231 - accuracy: 0.8320
# Epoch 64/100
# 87/87 [==============================] - 392s 4s/step - loss: 0.1202 - accuracy: 0.8374
# Epoch 65/100
# 87/87 [==============================] - 392s 4s/step - loss: 0.1166 - accuracy: 0.8393
# Epoch 66/100
# 87/87 [==============================] - 392s 4s/step - loss: 0.1159 - accuracy: 0.8413
# Epoch 67/100
# 87/87 [==============================] - 385s 4s/step - loss: 0.1176 - accuracy: 0.8355
# Epoch 68/100
# 87/87 [==============================] - 381s 4s/step - loss: 0.1154 - accuracy: 0.8380
# Epoch 69/100
# 87/87 [==============================] - 393s 4s/step - loss: 0.1162 - accuracy: 0.8391
# Epoch 70/100
# 87/87 [==============================] - 392s 4s/step - loss: 0.1161 - accuracy: 0.8368
# Epoch 71/100
# 87/87 [==============================] - 392s 4s/step - loss: 0.1127 - accuracy: 0.8396
# Epoch 72/100
# 87/87 [==============================] - 393s 4s/step - loss: 0.1086 - accuracy: 0.8455
# Epoch 73/100
# 87/87 [==============================] - 395s 5s/step - loss: 0.1195 - accuracy: 0.8304
# Epoch 74/100
# 87/87 [==============================] - 398s 5s/step - loss: 0.1159 - accuracy: 0.8358
# Epoch 75/100
# 87/87 [==============================] - 395s 5s/step - loss: 0.1129 - accuracy: 0.8397
# Epoch 76/100
# 87/87 [==============================] - 393s 4s/step - loss: 0.1168 - accuracy: 0.8354
# Epoch 77/100
# 87/87 [==============================] - 393s 4s/step - loss: 0.1154 - accuracy: 0.8327
# Epoch 78/100
# 87/87 [==============================] - 378s 4s/step - loss: 0.1124 - accuracy: 0.8403
# Epoch 79/100
# 87/87 [==============================] - 392s 4s/step - loss: 0.1127 - accuracy: 0.8382
# Epoch 80/100
# 87/87 [==============================] - 390s 4s/step - loss: 0.1076 - accuracy: 0.8445
# Epoch 81/100
# 87/87 [==============================] - 394s 5s/step - loss: 0.1129 - accuracy: 0.8358
# Epoch 82/100
# 87/87 [==============================] - 392s 4s/step - loss: 0.1076 - accuracy: 0.8422
# Epoch 83/100
# 87/87 [==============================] - 390s 4s/step - loss: 0.1169 - accuracy: 0.8302
# Epoch 84/100
# 87/87 [==============================] - 393s 4s/step - loss: 0.1094 - accuracy: 0.8416
# Epoch 85/100
# 87/87 [==============================] - 392s 4s/step - loss: 0.1118 - accuracy: 0.8363
# Epoch 86/100
# 87/87 [==============================] - 393s 4s/step - loss: 0.1093 - accuracy: 0.8405
# Epoch 87/100
# 56/87 [==================>...........] - ETA: 2:20 - loss: 0.1134 - accuracy: 0.8317
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
# Save model
#!mkdir -p model2
model.save('model/segmentation')
# Out:
# INFO:tensorflow:Assets written to: model2/my_model/assets
# INFO:tensorflow:Assets written to: model2/my_model/assets

# %%
# Load model
new_model = tf.keras.models.load_model('model/segmentation')

# %%
# loss curve
plt.title('Loss')
plt.plot(result.history['loss'], label='loss')
plt.legend(loc='center right')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc='center right');

# %%
# Evaluate the restored model
loss, acc = model.evaluate(x_test, y_test, verbose=2)
print('model accuracy: {:5.2f}%'.format(100 * acc))
# Out:
# 30/30 - 75s - loss: 0.1126 - accuracy: 0.8584 - 75s/epoch - 3s/step
# model accuracy: 85.84%

# %%
idx = 8
print(idx)
x=np.array(x_test[idx])
x=np.expand_dims(x,axis=0)
pred = model.predict(x, verbose=1)
pred = (pred>0.5).astype(np.uint8)
imshow(np.squeeze(pred[0]));
# Out:
# 8
# 1/1 [==============================] - 0s 202ms/step

# %%
imshow(x_test[idx]);

# %% [markdown]
# ### Exercise

# %% [markdown]
# Again, we should try to vary the model's parameters such as learning rates, loss function and epochs to see how the model's performance changes.
